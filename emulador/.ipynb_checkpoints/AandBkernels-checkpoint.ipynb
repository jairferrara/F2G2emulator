# %% [markdown]
# ### Configuration

# %%
import os
os.environ["PYTHONHASHSEED"] = "42"
# os.environ["TF_DETERMINISTIC_OPS"] = "42"
# os.environ["TF_CUDNN_DETERMINISTIC"] = "42"

import random

import time

import sklearn

import joblib

import numpy as np

import jax
import jax.numpy as jnp

import tensorflow as tf
import tensorflow.keras as K

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

import matplotlib.pyplot as plt

# %%
params = {
            "neurons" : [64, 512, 512, 4],    # The last one correspond to the output layer
        "activations" : ["tanh", "tanh", "tanh", "linear"],    # The last one correspond to the output layer
             "epochs" : 100,
                 "lr" : 5e-3,
               "loss" : "mse",
         "batch_size" : 256,
     "early_patience" : 10,
      "RLRonP_factor" : 0.6,
    "RLRonP_patience" : 7,
      "path_datasets" : "./../src/datasets/",
         "path_model" : "./../src/model/"
}

# %% [markdown]
# ### Pre-processing data

# %%
def loadData():
    """
    Lo que se resuelve en el script numérico es con fR0, no con log10fR0.
    """
    path_datasets = params["path_datasets"]
    
    train         = np.loadtxt(path_datasets + "train.txt",      skiprows=1)
    validation    = np.loadtxt(path_datasets + "validation.txt", skiprows=1)
    test          = np.loadtxt(path_datasets + "test.txt",       skiprows=1)

    # for dataset in [train, validation, test]:
    #     dataset[:, 5] = 10 ** dataset[:, 5]
        
    print("Samples size:\n")
    print(f"Train: {len(train)} || val & test: {len(test)}.")

    return train, validation, test

# %%
def _createScaler():
    """
    Se crea un Scaler global para toda la instancia y se impiden problemas con la aleatoriedad.
    """
    global SSi
    global SSo
    SSi = sklearn.preprocessing.StandardScaler()
    SSo = sklearn.preprocessing.StandardScaler()
    return 0

# %%
def scaleData(data_set):
    """
    Divide los 6 imputs y 4 outputs ded cada data set.

    Se crea 2 SS y 2 scalers para input y output. Los scalers solo se crean con train
    para impedir que el modelo sepa de antemano información de validation o test.
    """
    i_set, o_set = data_set[:,:6], data_set[:,6:]    # (z, k1, k2, x12, om, logf), (A, Ap, B, Bp)

    if "SSi" not in globals() and "SSo" not in globals():
        _createScaler()

        global scaler_i
        global scaler_o
        scaler_i = SSi.fit(i_set)
        scaler_o = SSo.fit(o_set)
        
    return [scaler_i.transform(i_set), scaler_o.transform(o_set)]

# %% [markdown]
# ### Model & training

# %%
def _createModel():
    """
    La arquitectura de la red está descrita por el dict arqui. 
    
    Es mutables para realizar muchas pruebas, pero el input y output siempre son los mismo.
    """
    neurons     = params["neurons"]
    activations = params["activations"]
    lr          = params["lr"]
    loss        = params["loss"]

    model = K.Sequential()
    model.add(K.Input(shape=(6,)))
    for n, func in zip(neurons, activations):
        model.add(K.layers.Dense(n, activation=func))

    model.compile(
        optimizer=K.optimizers.Adam(learning_rate=lr),
        loss=loss
    )

    model.summary()
    return model

# %%
def _callbacks():
    ES = K.callbacks.EarlyStopping
    RLRonP = K.callbacks.ReduceLROnPlateau

    early_patience  = params["early_patience"]
    RLRonP_factor   = params["RLRonP_factor"]
    RLRonP_patience = params["RLRonP_patience"]
    
    call_1 = ES(
        monitor               = 'val_loss',
        mode                  = "min",
        patience              = early_patience,
        restore_best_weights  = True,
        verbose               = 1,
    )

    call_2 = RLRonP(
        monitor   = 'val_loss',
        factor    = RLRonP_factor,
        patience  = RLRonP_patience,
        min_lr    = 1e-6,
        verbose   = 1
    )
            
    return [call_1, call_2]

# %%
def trainModel(scaled_train, scaled_val):
    """
    shuffle=True no afecta a Sobol ya que solo está cambiando el orden de cada uno de los sets,
    pero cada set ya está cubriendo todo el espacio.
    """
    epochs     = params["epochs"]
    batch_size = params["batch_size"]

    x_train, y_train = scaled_train[0], scaled_train[1]
    x_val, y_val     = scaled_val[0], scaled_val[1]
    model = _createModel()

    history = model.fit(
        x_train, y_train,
        batch_size=batch_size,
        epochs=epochs,
        shuffle=True,
        validation_data=(x_val, y_val),
        verbose=2,
        callbacks=_callbacks(),
    )

    return history, model

# %%
def saveModel(model):
    path_model = params["path_model"]
    
    joblib.dump(scaler_i, path_model + "scaler_i.pkl")
    joblib.dump(scaler_o, path_model + "scaler_o.pkl")
    
    model.save(path_model + "model.keras")

# %% [markdown]
# ### Post-processing data

# %%
def _unScaleData(data):
    """
    Aplica el escalamiento inverso para obtener los valores en los rangos originales.bien. 
    """
    return scaler_o.inverse_transform(data)

# %% [markdown]
# ### Data validation

# %%
def _makePrediction(model, x_data):
    batch_size = params["batch_size"]

    prediction = model.predict(
        x_data,
        batch_size=batch_size,
        verbose=0,
    )

    return prediction

# %%
def relError(model, scaled_data):
    scaled_x, scaled_y = scaled_data[0], scaled_data[1]
    scaled_y_predic    = _makePrediction(model, scaled_x)

    unscaled_y         = _unScaleData(scaled_y)
    unscaled_y_predic  = _unScaleData(scaled_y_predic)
        
    #unscaled_rel_error = (unscaled_y - unscaled_y_predic) * 100
    unscaled_rel_error = (1 - unscaled_y_predic / unscaled_y) * 100

    return unscaled_rel_error

# %%
def calcPercentil(error):
    r_names = ["A", "Ap", "B", "Bp"]
    rows = len(r_names)

    print(f"Percentil 99 for unscaled data in relative percentual error")
    print(20 * "=")
    for r in range(rows):
        perc = np.percentile(np.abs(error.T[r]), 99)
        print(f"{r_names[r]:>4}: {perc:.6f}%")
    print(20 * "=")

# %% [markdown]
# ### Plotting

# %%
def plotLossFunction(history):
    succ_epochs = len(history.history['loss'])
    plt.figure(figsize=(10,7))
    x_axis = np.linspace(1, succ_epochs, succ_epochs)
    plt.semilogy(x_axis, history.history['loss'], 'r--', label='Train')
    plt.semilogy(x_axis, history.history['val_loss'], 'b-', label='Validation')
    plt.legend()
    plt.xlabel('epochs')
    plt.ylabel('loss')
    plt.show()

# %%
def plotRelError(rel_error):
    rows, cols = 2, 2
    names = ["A", "Ap", "B", "Bp"]
    
    fig, axes = plt.subplots(rows, cols, figsize=(14,10))

    for c in range(cols):
        for r in range(rows):
            axes[r, c].hist(
                rel_error.T[r * 2 + c],
                bins=40,
                #range=(-1, 1),
                log=True,
                orientation="horizontal",
            )
            axes[r, c].set_xlabel("Frecuency", fontsize=18)
            axes[r, c].set_ylabel(r"$\Delta y$%", fontsize=18)
            axes[r, c].tick_params(
                axis="both",
                labelsize=14,
            )
            axes[r, c].set_title(f"Error relativo porcentual de {names[r * 2 + c]}")

    plt.show()

# %% [markdown]
# ### Evaluation

# %%
train, validation, test = loadData()
# Out:
# Samples size:
#
# Train: 4194304 || val & test: 1048576.

# %%
# %%time
scaled_train = scaleData(train)
scaled_val = scaleData(validation)

history, model = trainModel(scaled_train, scaled_val)
plotLossFunction(history)
saveModel(model)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │        33,280 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │         2,052 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 298,436 (1.14 MB)
#  Trainable params: 298,436 (1.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 16384/16384 - 35s - 2ms/step - loss: 0.0257 - val_loss: 0.0056 - learning_rate: 0.0050
# Epoch 2/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0074 - val_loss: 0.0069 - learning_rate: 0.0050
# Epoch 3/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0063 - val_loss: 0.0043 - learning_rate: 0.0050
# Epoch 4/100
# 16384/16384 - 25s - 2ms/step - loss: 0.0058 - val_loss: 0.0070 - learning_rate: 0.0050
# Epoch 5/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0054 - val_loss: 0.0025 - learning_rate: 0.0050
# Epoch 6/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0055 - val_loss: 0.0079 - learning_rate: 0.0050
# Epoch 7/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0052 - val_loss: 0.0039 - learning_rate: 0.0050
# Epoch 8/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0051 - val_loss: 0.0044 - learning_rate: 0.0050
# Epoch 9/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0050 - val_loss: 0.0061 - learning_rate: 0.0050
# Epoch 10/100
# 16384/16384 - 30s - 2ms/step - loss: 0.0048 - val_loss: 0.0026 - learning_rate: 0.0050
# Epoch 11/100
# 16384/16384 - 25s - 2ms/step - loss: 0.0049 - val_loss: 0.0081 - learning_rate: 0.0050
# Epoch 12/100
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0029999999329447745.
# 16384/16384 - 26s - 2ms/step - loss: 0.0049 - val_loss: 0.0055 - learning_rate: 0.0050
# Epoch 13/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0020 - val_loss: 0.0013 - learning_rate: 0.0030
# Epoch 14/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0019 - val_loss: 0.0010 - learning_rate: 0.0030
# Epoch 15/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0019 - val_loss: 0.0016 - learning_rate: 0.0030
# Epoch 16/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0018 - val_loss: 0.0019 - learning_rate: 0.0030
# Epoch 17/100
# 16384/16384 - 29s - 2ms/step - loss: 0.0018 - val_loss: 0.0013 - learning_rate: 0.0030
# Epoch 18/100
# 16384/16384 - 26s - 2ms/step - loss: 0.0017 - val_loss: 0.0015 - learning_rate: 0.0030
# Epoch 19/100
# 16384/16384 - 28s - 2ms/step - loss: 0.0017 - val_loss: 0.0016 - learning_rate: 0.0030
# Epoch 20/100
# 16384/16384 - 27s - 2ms/step - loss: 0.0017 - val_loss: 0.0017 - learning_rate: 0.0030
# Epoch 21/100
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.001800000015646219.
# 16384/16384 - 30s - 2ms/step - loss: 0.0017 - val_loss: 0.0053 - learning_rate: 0.0030
# Epoch 22/100
# 16384/16384 - 31s - 2ms/step - loss: 7.6563e-04 - val_loss: 4.9125e-04 - learning_rate: 0.0018
# Epoch 23/100
# 16384/16384 - 31s - 2ms/step - loss: 7.3197e-04 - val_loss: 0.0012 - learning_rate: 0.0018
# Epoch 24/100
# 16384/16384 - 31s - 2ms/step - loss: 7.1743e-04 - val_loss: 8.7708e-04 - learning_rate: 0.0018
# Epoch 25/100
# 16384/16384 - 30s - 2ms/step - loss: 7.0080e-04 - val_loss: 4.2796e-04 - learning_rate: 0.0018
# Epoch 26/100
# 16384/16384 - 30s - 2ms/step - loss: 6.9329e-04 - val_loss: 4.5467e-04 - learning_rate: 0.0018
# Epoch 27/100
# 16384/16384 - 31s - 2ms/step - loss: 6.8673e-04 - val_loss: 6.1394e-04 - learning_rate: 0.0018
# Epoch 28/100
# 16384/16384 - 31s - 2ms/step - loss: 6.5502e-04 - val_loss: 7.6752e-04 - learning_rate: 0.0018
# Epoch 29/100
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0010799999814480542.
# 16384/16384 - 30s - 2ms/step - loss: 6.7848e-04 - val_loss: 6.2906e-04 - learning_rate: 0.0018
# Epoch 30/100
# 16384/16384 - 31s - 2ms/step - loss: 3.1719e-04 - val_loss: 2.6083e-04 - learning_rate: 0.0011
# Epoch 31/100
# 16384/16384 - 30s - 2ms/step - loss: 3.0687e-04 - val_loss: 3.7683e-04 - learning_rate: 0.0011
# Epoch 32/100
# 16384/16384 - 31s - 2ms/step - loss: 3.0357e-04 - val_loss: 3.2613e-04 - learning_rate: 0.0011
# Epoch 33/100
# 16384/16384 - 31s - 2ms/step - loss: 3.0185e-04 - val_loss: 2.5091e-04 - learning_rate: 0.0011
# Epoch 34/100
# 16384/16384 - 31s - 2ms/step - loss: 2.9112e-04 - val_loss: 3.3567e-04 - learning_rate: 0.0011
# Epoch 35/100
# 16384/16384 - 30s - 2ms/step - loss: 2.8917e-04 - val_loss: 2.8023e-04 - learning_rate: 0.0011
# Epoch 36/100
# 16384/16384 - 30s - 2ms/step - loss: 2.8810e-04 - val_loss: 1.7871e-04 - learning_rate: 0.0011
# Epoch 37/100
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0006479999748989939.
# 16384/16384 - 31s - 2ms/step - loss: 2.8675e-04 - val_loss: 3.2338e-04 - learning_rate: 0.0011
# Epoch 38/100
# 16384/16384 - 31s - 2ms/step - loss: 1.4585e-04 - val_loss: 1.5689e-04 - learning_rate: 6.4800e-04
# Epoch 39/100
# 16384/16384 - 30s - 2ms/step - loss: 1.4310e-04 - val_loss: 1.5012e-04 - learning_rate: 6.4800e-04
# Epoch 40/100
# 16384/16384 - 31s - 2ms/step - loss: 1.4228e-04 - val_loss: 1.5276e-04 - learning_rate: 6.4800e-04
# Epoch 41/100
# 16384/16384 - 33s - 2ms/step - loss: 1.3627e-04 - val_loss: 1.5148e-04 - learning_rate: 6.4800e-04
# Epoch 42/100
# 16384/16384 - 31s - 2ms/step - loss: 1.3690e-04 - val_loss: 1.4643e-04 - learning_rate: 6.4800e-04
# Epoch 43/100
# 16384/16384 - 31s - 2ms/step - loss: 1.3285e-04 - val_loss: 1.1073e-04 - learning_rate: 6.4800e-04
# Epoch 44/100
# 16384/16384 - 31s - 2ms/step - loss: 1.3268e-04 - val_loss: 1.2746e-04 - learning_rate: 6.4800e-04
# Epoch 45/100
#
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0003887999919243157.
# 16384/16384 - 30s - 2ms/step - loss: 1.3184e-04 - val_loss: 1.0000e-04 - learning_rate: 6.4800e-04
# Epoch 46/100
# 16384/16384 - 30s - 2ms/step - loss: 7.3666e-05 - val_loss: 9.3488e-05 - learning_rate: 3.8880e-04
# Epoch 47/100
# 16384/16384 - 30s - 2ms/step - loss: 7.3144e-05 - val_loss: 7.4732e-05 - learning_rate: 3.8880e-04
# Epoch 48/100
# 16384/16384 - 31s - 2ms/step - loss: 7.2792e-05 - val_loss: 8.4151e-05 - learning_rate: 3.8880e-04
# Epoch 49/100
# 16384/16384 - 31s - 2ms/step - loss: 7.1007e-05 - val_loss: 8.1015e-05 - learning_rate: 3.8880e-04
# Epoch 50/100
# 16384/16384 - 31s - 2ms/step - loss: 6.9054e-05 - val_loss: 1.3956e-04 - learning_rate: 3.8880e-04
# Epoch 51/100
# 16384/16384 - 30s - 2ms/step - loss: 6.7541e-05 - val_loss: 7.2952e-05 - learning_rate: 3.8880e-04
# Epoch 52/100
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 0.0002332799951545894.
# 16384/16384 - 31s - 2ms/step - loss: 6.6583e-05 - val_loss: 7.4419e-05 - learning_rate: 3.8880e-04
# Epoch 53/100
# 16384/16384 - 29s - 2ms/step - loss: 4.4248e-05 - val_loss: 5.7929e-05 - learning_rate: 2.3328e-04
# Epoch 54/100
# 16384/16384 - 29s - 2ms/step - loss: 4.3469e-05 - val_loss: 5.8811e-05 - learning_rate: 2.3328e-04
# Epoch 55/100
# 16384/16384 - 29s - 2ms/step - loss: 4.2751e-05 - val_loss: 6.1271e-05 - learning_rate: 2.3328e-04
# Epoch 56/100
# 16384/16384 - 28s - 2ms/step - loss: 4.2704e-05 - val_loss: 6.5309e-05 - learning_rate: 2.3328e-04
# Epoch 57/100
# 16384/16384 - 30s - 2ms/step - loss: 4.1383e-05 - val_loss: 5.8131e-05 - learning_rate: 2.3328e-04
# Epoch 58/100
# 16384/16384 - 30s - 2ms/step - loss: 4.0521e-05 - val_loss: 6.0336e-05 - learning_rate: 2.3328e-04
# Epoch 59/100
# 16384/16384 - 31s - 2ms/step - loss: 4.0680e-05 - val_loss: 5.0810e-05 - learning_rate: 2.3328e-04
# Epoch 60/100
# 16384/16384 - 29s - 2ms/step - loss: 4.0222e-05 - val_loss: 5.3693e-05 - learning_rate: 2.3328e-04
# Epoch 61/100
# 16384/16384 - 29s - 2ms/step - loss: 3.9673e-05 - val_loss: 5.2282e-05 - learning_rate: 2.3328e-04
# Epoch 62/100
# 16384/16384 - 29s - 2ms/step - loss: 3.8452e-05 - val_loss: 5.1977e-05 - learning_rate: 2.3328e-04
# Epoch 63/100
# 16384/16384 - 27s - 2ms/step - loss: 3.8588e-05 - val_loss: 4.7638e-05 - learning_rate: 2.3328e-04
# Epoch 64/100
# 16384/16384 - 29s - 2ms/step - loss: 3.8108e-05 - val_loss: 5.0081e-05 - learning_rate: 2.3328e-04
# Epoch 65/100
# 16384/16384 - 29s - 2ms/step - loss: 3.6939e-05 - val_loss: 5.0511e-05 - learning_rate: 2.3328e-04
# Epoch 66/100
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 0.00013996799534652383.
# 16384/16384 - 26s - 2ms/step - loss: 3.6876e-05 - val_loss: 4.8639e-05 - learning_rate: 2.3328e-04
# Epoch 67/100
# 16384/16384 - 26s - 2ms/step - loss: 2.6902e-05 - val_loss: 4.2583e-05 - learning_rate: 1.3997e-04
# Epoch 68/100
# 16384/16384 - 26s - 2ms/step - loss: 2.6806e-05 - val_loss: 4.5143e-05 - learning_rate: 1.3997e-04
# Epoch 69/100
# 16384/16384 - 26s - 2ms/step - loss: 2.6312e-05 - val_loss: 4.4321e-05 - learning_rate: 1.3997e-04
# Epoch 70/100
# 16384/16384 - 26s - 2ms/step - loss: 2.5636e-05 - val_loss: 4.0880e-05 - learning_rate: 1.3997e-04
# Epoch 71/100
# 16384/16384 - 26s - 2ms/step - loss: 2.5745e-05 - val_loss: 4.0500e-05 - learning_rate: 1.3997e-04
# Epoch 72/100
# 16384/16384 - 26s - 2ms/step - loss: 2.5542e-05 - val_loss: 4.0069e-05 - learning_rate: 1.3997e-04
# Epoch 73/100
#
# Epoch 73: ReduceLROnPlateau reducing learning rate to 8.398079371545464e-05.
# 16384/16384 - 25s - 2ms/step - loss: 2.5358e-05 - val_loss: 4.6609e-05 - learning_rate: 1.3997e-04
# Epoch 74/100
# 16384/16384 - 26s - 2ms/step - loss: 2.0426e-05 - val_loss: 3.8618e-05 - learning_rate: 8.3981e-05
# Epoch 75/100
# 16384/16384 - 27s - 2ms/step - loss: 2.0539e-05 - val_loss: 3.5222e-05 - learning_rate: 8.3981e-05
# Epoch 76/100
# 16384/16384 - 26s - 2ms/step - loss: 2.0221e-05 - val_loss: 3.5743e-05 - learning_rate: 8.3981e-05
# Epoch 77/100
# 16384/16384 - 26s - 2ms/step - loss: 1.9562e-05 - val_loss: 3.4757e-05 - learning_rate: 8.3981e-05
# Epoch 78/100
# 16384/16384 - 26s - 2ms/step - loss: 1.9675e-05 - val_loss: 3.3913e-05 - learning_rate: 8.3981e-05
# Epoch 79/100
# 16384/16384 - 26s - 2ms/step - loss: 1.9667e-05 - val_loss: 3.6662e-05 - learning_rate: 8.3981e-05
# Epoch 80/100
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 5.038847448304296e-05.
# 16384/16384 - 26s - 2ms/step - loss: 1.9382e-05 - val_loss: 3.2431e-05 - learning_rate: 8.3981e-05
# Epoch 81/100
# 16384/16384 - 26s - 2ms/step - loss: 1.6759e-05 - val_loss: 3.2349e-05 - learning_rate: 5.0388e-05
# Epoch 82/100
# 16384/16384 - 26s - 2ms/step - loss: 1.7433e-05 - val_loss: 3.5121e-05 - learning_rate: 5.0388e-05
# Epoch 83/100
# 16384/16384 - 27s - 2ms/step - loss: 1.7145e-05 - val_loss: 3.1152e-05 - learning_rate: 5.0388e-05
# Epoch 84/100
# 16384/16384 - 26s - 2ms/step - loss: 1.6970e-05 - val_loss: 3.1649e-05 - learning_rate: 5.0388e-05
# Epoch 85/100
# 16384/16384 - 27s - 2ms/step - loss: 1.6351e-05 - val_loss: 2.9812e-05 - learning_rate: 5.0388e-05
# Epoch 86/100
# 16384/16384 - 29s - 2ms/step - loss: 1.6008e-05 - val_loss: 2.9498e-05 - learning_rate: 5.0388e-05
# Epoch 87/100
#
# Epoch 87: ReduceLROnPlateau reducing learning rate to 3.023308381671086e-05.
# 16384/16384 - 28s - 2ms/step - loss: 1.6467e-05 - val_loss: 3.3471e-05 - learning_rate: 5.0388e-05
# Epoch 88/100
# 16384/16384 - 27s - 2ms/step - loss: 1.5203e-05 - val_loss: 2.7915e-05 - learning_rate: 3.0233e-05
# Epoch 89/100
# 16384/16384 - 26s - 2ms/step - loss: 1.5071e-05 - val_loss: 2.9022e-05 - learning_rate: 3.0233e-05
# Epoch 90/100
# 16384/16384 - 25s - 2ms/step - loss: 1.4732e-05 - val_loss: 2.9308e-05 - learning_rate: 3.0233e-05
# Epoch 91/100
# 16384/16384 - 26s - 2ms/step - loss: 1.4306e-05 - val_loss: 2.9529e-05 - learning_rate: 3.0233e-05
# Epoch 92/100
# 16384/16384 - 26s - 2ms/step - loss: 1.4189e-05 - val_loss: 2.9400e-05 - learning_rate: 3.0233e-05
# Epoch 93/100
# 16384/16384 - 25s - 2ms/step - loss: 1.4337e-05 - val_loss: 2.9433e-05 - learning_rate: 3.0233e-05
# Epoch 94/100
#
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1.8139850726583973e-05.
# 16384/16384 - 25s - 2ms/step - loss: 1.4669e-05 - val_loss: 2.8898e-05 - learning_rate: 3.0233e-05
# Epoch 95/100
# 16384/16384 - 26s - 2ms/step - loss: 1.4533e-05 - val_loss: 2.7837e-05 - learning_rate: 1.8140e-05
# Epoch 96/100
# 16384/16384 - 27s - 2ms/step - loss: 1.4626e-05 - val_loss: 2.6710e-05 - learning_rate: 1.8140e-05
# Epoch 97/100
# 16384/16384 - 29s - 2ms/step - loss: 1.4272e-05 - val_loss: 2.8015e-05 - learning_rate: 1.8140e-05
# Epoch 98/100
# 16384/16384 - 26s - 2ms/step - loss: 1.3824e-05 - val_loss: 2.7608e-05 - learning_rate: 1.8140e-05
# Epoch 99/100
# 16384/16384 - 26s - 2ms/step - loss: 1.3216e-05 - val_loss: 2.7081e-05 - learning_rate: 1.8140e-05
# Epoch 100/100
# 16384/16384 - 26s - 2ms/step - loss: 1.2982e-05 - val_loss: 2.7718e-05 - learning_rate: 1.8140e-05
# Restoring model weights from the end of the best epoch: 96.
# CPU times: user 1h 2min 51s, sys: 6min 42s, total: 1h 9min 33s
# Wall time: 47min

# %%
scaled_test = scaleData(test)

unscaled_rel_error = relError(model, scaled_test)
calcPercentil(unscaled_rel_error)
# Out:
# Percentil 99 for unscaled data in relative percentual error
# ====================
#    A: 0.029097%
#   Ap: 33.220256%
#    B: 0.013816%
#   Bp: 29.817168%
# ====================
